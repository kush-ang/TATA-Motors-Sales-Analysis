# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("TATA_car_sales_cleaned.csv")
print(df.shape)
# Out:
# (250000, 34)

# %%
engine = create_engine('mysql+mysqlconnector://root:XXXXXX@localhost/tata_motors')
print("Connected!")
# Out:
# Connected!

# %%
df.to_sql('tata_sales', con=engine, if_exists='replace', index=False, chunksize=1000)
# Out:
# 250000
